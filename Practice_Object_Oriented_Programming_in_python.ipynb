# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahhsamir/Datastructure-Algorithms-in-python/blob/main/Practice_Object_Oriented_Programming_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <span> In this notebook I'm recapping what I read about oop and practising these concepts in Python.
# </span>
#
# <span>
# Reference: <a href = "https://searchapparchitecture.techtarget.com/definition/object-oriented-programming-OOP"> searchapparchitecture </a>
# </span>

# %% [markdown]
# # Object Oriented Programming
# 1. (OOP) **is a computer programming model** that organizes software design around data, or objects, rather than functions and logic.
# 2. An object can be defined as a data field that has unique attributes and behavior.
# 3. This approach to programming is well-suited for **programs that are large, complex and actively updated or maintained**
# 4. OOP can be used for manufacturing system simulation software.
#
# The first step in OOP is to **collect all of the objects** a programmer wants to manipulate and identify how they relate to each other -- an exercise known as data modeling.
#
# The figure as show:
#
# ![whatis-object_oriented_programming_half_column_desktop.png](data:image/png;base64,...)
#
#
# #What is the structure of object-oriented programming?
# The structure, or building blocks, of object-oriented programming include the following:
#
# 1. **Classes** are user-defined data types that act as the blueprint for individual objects, attributes and methods.
#
# 2. **Objects** are instances of a class created with specifically defined data. Objects can correspond to real-world objects or an abstract entity. When class is defined initially, the description is the only object that is defined.
#
# 3. **Methods** are functions that are defined inside a class that describe the behaviors of an object. Each method contained in class definitions starts with a reference to an instance object. Additionally, the subroutines contained in an object are called instance methods. Programmers use methods for reusability or keeping functionality encapsulated inside one object at a time.
#
# 4. **Attributes** are defined in the class template and represent the state of an object. Objects will have data stored in the attributes field. Class attributes belong to the class itself

# %% [markdown]
# #What are the main principles of OOP?
#
# 1. **Encapsulation**  :
#   *   All important information is contained inside an object and only select information is exposed.
#   *   The implementation and state of each object are privately held inside a defined class.
#   * Other objects do not have access to this class or the authority to make changes. They are only able to call a list of public functions or methods.
#   *  This characteristic of data hiding provides greater program security and avoids unintended data corruption.
# ![Encapsulation-illustration-with-capsule.png](data:image/png;base64,...)
#
# ---
# 2. **Abstraction**:
#     * Objects only reveal internal mechanisms that are relevant for the use of other objects, hiding any unnecessary implementation code
#     * The derived class can have its functionality extended
#     * This concept can help developers more easily make additional changes or additions over time
#
# ---
# 3. **Inheritance**:
#     * Classes can reuse code from other classes.
#     * Enabling developers to reuse common logic.
#     * This property of OOP forces a more thorough data analysis, reduces development time and ensures a higher level of accuracy.
#     ![1_rddNpQyOeBl_jQ3Rmet5dg.png](data:image/png;base64,...)
#
# ---
# 4. **Polymorphism** :
#     * Objects are designed to share behaviors and they can take on more than one form
#     * The program will determine which meaning or usage is necessary for each execution of that object from a parent class
#     * Allows different types of objects to pass through the same interface
#     * Reducing the need to duplicate code
#     ![original.png](data:image/png;base64,...)

# %% [markdown]
# #Recap
# ![OOP_4p.png](data:image/png;base64,...)

# %% [markdown]
# #Instance Attributes, Methods and Dunder Functions

# %%
class Player:
  player_count = 0
  def __init__(self,first_name,last_name,number,position):
    self.first_name = first_name
    self.last_name = last_name
    self.number = number
    self.position = position
    self.rate = []
    Player.player_count += 1

  @staticmethod
  def hello():
    return 'hello to player class'
  
  @classmethod
  def count_player(cls):
    return "we have {} players".format(cls.player_count)

  
  def get_Name(self):
    return f"{self.first_name} {self.last_name}"
  
  def get_Details(self):
    return "this player called {} {} , his number is {} and his position is {}".format(self.first_name,self.last_name,self.number,self.position)

  
  
  def __repr__(self):
    return "welcome to mr {} object ,number is {} and his different rates is {}".format(self.last_name,self.number,self.rate)
  
  def __len__(self):
    return len(rate)

# %%
player_1 = Player("mohamed","salah","11","RW")
player_2 = Player("sadio","mane","10","LW")
player_3 = Player("roberto","firmino","9","CF")

# %%
Player.count_player()
# Out:
# 'we have 3 players'

# %%
Player.hello()
# Out:
# 'hello to player class'

# %%
print(player_1.get_Name())
# Out:
# mohamed salah

# %%
print(player_1.get_Details())
# Out:
# this player called mohamed salah , his number is 11 and his position is RW

# %%
player_1.rate.append(7.5)

# %%
print(player_1)
# Out:
# welcome to mr salah object ,number is 11 and his different rates is [7.5]

# %%
player_1.__class__
# Out:
# __main__.Player

# %%
dir(player_1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'count_player',
#  'first_name',
#  'get_Details',
#  'get_Name',
#  'hello',
#  'last_name',
#  'number',
#  'player_count',
#  'position',
#  'rate']

# %% [markdown]
# #Inheritance

# %% [markdown]
# Single inheritance

# %%
class Food:
  def __init__(self,name,price):
    self.name = name
    self.price = price
  def eat(self):
    print("Eatting from base class")


class Spfood(Food):
  def __init__(self,name,price,amount):
    super().__init__(name,price)
    self.amount = amount 
    print(f"{self.name} Is Created From Derived Class And Price Is {self.price} And Amount Is {self.amount}")
  
  def get_Details(self):
    print('speical food order')

# %%
f1 = Food("pizza",150)

# %%
f2 = Spfood("apple",20,5)
# Out:
# apple Is Created From Derived Class And Price Is 20 And Amount Is 5

# %%
f2.eat()
# Out:
# Eatting from base class

# %%
f2.get_Details()
# Out:
# speical food order

# %% [markdown]
# Multiple inheritance

# %%
class BaseOne:

  def __init__(self):

    print("Base One")

  def func_one(self):

    print("One")

class BaseTwo:

  def __init__(self):

    print("Base Two")

  def func_two(self):

    print("Two")

class Derived(BaseOne, BaseTwo):

  pass

my_var = Derived()

# print(Derived.mro())

print(my_var.func_one)
print(my_var.func_two)

my_var.func_one()
my_var.func_two()
# Out:
# Base One
# <bound method BaseOne.func_one of <__main__.Derived object at 0x7f4c16a3cb10>>
# <bound method BaseTwo.func_two of <__main__.Derived object at 0x7f4c16a3cb10>>
# One
# Two

# %% [markdown]
# # Polymorphism

# %%
class A:

  def do(self):

    print("From Class A")

    raise NotImplementedError("Derived Class Must Implement This Method")

class B(A):

  def do(self):

    print("From Class B")

class C(A):

  def do(self):

    print("From Class C")

my_instance = B()
my_instance.do()
# Out:
# From Class B

# %% [markdown]
# # Encapsulation
#
# <span> Reference: <a href = "https://www.faceprep.in/python/encapsulation-in-python/"> faceprep </a>
# </span>

# %% [markdown]
# ## Why Do We Need Encapsulation?
# 1. Encapsulation acts as a protective layer by ensuring that, access to wrapped data is not possible by any code defined outside the class
#
# 2. Encapsulation provides security by hiding the data from the outside world
#
# 3. In Python, Encapsulation can be achieved by declaring the data members of a class either as **private or protected**. In Python, 'Private' and 'Protected' are called **Access Modifiers**

# %% [markdown]
# ## Encapsulation Using Private Members
# 1. If we declare any variable or method as **private**, then they can be accessed **only within the class** in which they are defined
#
# 2. Private members are preceded by two underscores

# %%
class std:
  __id = 0 #
  __password = 0
  

test = std() #object created for the class 'Rectangle'#printing values of the private variable outside the class using the object created for the class 'Rectangle'
print(test.__id)
print(test.__password)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d322290fe0e1> in <module>()
#       5
#       6 test = std() #object created for the class 'Rectangle'#printing values of the private variable outside the class using the object created for the class 'Rectangle'
# ----> 7 print(test.__id)
#       8 print(test.__password)
#
# AttributeError: 'std' object has no attribute '__id'

# %%
test._std__id
# Out:
# 0

# %% [markdown]
# ## Encapsulation Using Protected Members
# 1. Protected members can be accessed within the class in which they are defined and **also within the derived classes**
#
# 2. In Python, protected members are preceded by a single underscore.

# %%
class Shape:
  _length = 10 
  _breadth = 20
  
class Circle(Shape):
  def __init__(self):
    print(self._length)
    print(self._breadth)

cr = Circle()
#printing protected variablesoutsidethe class 'Shape' in which they are defined
print(cr.length)
print(cr.breadth)
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b87b4e596ed3> in <module>()
#      10 cr = Circle()
#      11 #printing protected variablesoutsidethe class 'Shape' in which they are defined
# ---> 12 print(cr.length)
#      13 print(cr.breadth)
#
# AttributeError: 'Circle' object has no attribute 'length'

# %% [markdown]
# # Abstraction
# <span> Reference: <a href = "https://www.faceprep.in/python/abstraction-in-python/"> faceprep </a>
# </span>

# %% [markdown]
# **Abstraction** in Python is the process of hiding the real implementation of an application from the user and emphasizing only on usage of it
#
# Examples:
# 1. consider you have bought a new electronic gadget. Along with the gadget, you get a user guide, instructing how to use the application, but this user guide has no info regarding the internal working of the gadget
#
# 2. when you use TV remote, you do not know how pressing a key in the remote changes the channel internally on the TV. You just know that pressing + volume key will increase the volume.

# %% [markdown]
# ## Why Do We Need Abstraction?
# Through the process of abstraction in Python, a programmer can hide all the irrelevant data/process of an application in order to reduce complexity and increase efficiency.

# %% [markdown]
# ## Example in python

# %%
from abc import ABCMeta, abstractmethod

class Sports(metaclass=ABCMeta):

  @abstractmethod
  def indvidual(self):

    pass

  @abstractmethod
  def team(self):

    pass
  @staticmethod
  def greeting():
    return "welcome to sports class!"

class Football(Sports):

  def team(self):

    return "Yes"


class Tennis(Sports):

  def team(self):

    return "No"

  def indvidual(self):

    return "Yes"

sport = Tennis()

print(sport.indvidual())

print(Sports.greeting())
# Out:
# Yes
# welcome to sports class!
